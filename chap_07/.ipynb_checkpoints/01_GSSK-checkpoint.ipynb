# %% [markdown]
# # Hyperparameter Tuning via Scikit-Learn
#
# ## GridSearch
#
# ### Loading Libraries

# %%
# Numerical Computing
import numpy as np

# Data Manipulation
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt

# Scikit-Learn
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.metrics import f1_score, make_scorer
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV

# %% [markdown]
# ### Loading Data

# %%
df = pd.read_csv("/Users/joaquinromero/Desktop/HPTP/data/train.csv", sep=";")

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df['y'] = df['y'].map({'yes':1,'no':0})

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome  y
# 0  unknown    5   may       261         1     -1         0  unknown  0
# 1  unknown    5   may       151         1     -1         0  unknown  0
# 2  unknown    5   may        76         1     -1         0  unknown  0
# 3  unknown    5   may        92         1     -1         0  unknown  0
# 4  unknown    5   may       198         1     -1         0  unknown  0

# %% [markdown]
# ## GridSearch

# %%
df_train, df_test = train_test_split(df,
                                     test_size=0.1,
                                     random_state=0)

# %% [markdown]
# #### Placing & Gathering Numerical Features

# %%
X_train_numerical = df_train.select_dtypes(include=np.number).drop(columns=["y"])

y_train = df_train['y']

# %%
X_test_numerical = df_test.select_dtypes(include=np.number).drop(columns=["y"])

y_test = df_test['y']

# %% [markdown]
# #### Fitting Model on Training Data:

# %%
# Placing Model
model = RandomForestClassifier(random_state=0)

# Fitting Model
model.fit(X_train_numerical, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %% [markdown]
# #### Evaluating on Test Data

# %%
y_pred = model.predict(X_test_numerical)

print(f1_score(y_test, y_pred))
# Out:
# 0.43013365735115433

# %% [markdown]
# #### Hyperparamater Space: Dictionary

# %%
hyperparameter_space = {
    "n_estimators": [25, 50, 100, 150, 200],
    "criterion": ["gini", "entropy"],
    "max_depth": [3, 5, 10, 15, 20, None],
    "class_weight": ["balanced", "balanced_subsampe"],
    "min_samples_split": [0.01, 0.1, 0.25, 0.5, 0.75, 1.0],
}

# %%
# Placing Model
model = RandomForestClassifier(random_state=0)

# %%
# GridSearchCV Class
clf = GridSearchCV(model, hyperparameter_space, scoring='f1', cv=5, n_jobs=-1, refit=True)

# %%
# Fitting clf
clf.fit(X_train_numerical, y_train)
# Out:
# /opt/anaconda3/envs/HPTP/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 1800 fits failed out of a total of 3600.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 845 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/HPTP/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/HPTP/lib/python3.10/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/opt/anaconda3/envs/HPTP/lib/python3.10/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/anaconda3/envs/HPTP/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'class_weight' parameter of RandomForestClassifier must be a str among {'balanced_subsample', 'balanced'}, an instance of 'dict', an instance of 'list' or None. Got 'balanced_subsampe' instead.
#
# --------------------------------------------------------------------------------
# 955 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/HPTP/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/HPTP/lib/python3.10/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/opt/anaconda3/envs/HPTP/lib/python3.10/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/anaconda3/envs/HPTP/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'class_weight' parameter of RandomForestClassifier must be a str among {'balanced', 'balanced_subsample'}, an instance of 'dict', an instance of 'list' or None. Got 'balanced_subsampe' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/anaconda3/envs/HPTP/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.44402295 0.45395008 0.45404899 0.45373378 0.45526427 0.44508592
#  0.44819157 0.44563732 0.44132109 0.44756518 0.40702186 0.41185377
#  0.4064825  0.39897224 0.40422815 0.39342261 0.40698168 0.40366102
#  0.40107869 0.41461459 0.08386316 0.12583412 0.12583412 0.12583412
#  0.12587351 0.08386316 0.12583412 0.12583412 0.12583412 0.12587351
#  0.40788128 0.42218528 0.08386316 0.12583412 0.12583412 0.12583412
#  0.12587351 0.08386316 0.12583412 0.12583412 0.12583412 0.12587351
#  0.48965523 0.49273834 0.49277509 0.49424731 0.49370291 0.44460767
#  0.44453048 0.44623658 0.44633082 0.44856596 0.41726325 0.41506144
#  0.4090155  0.40429177 0.41038912 0.40974133 0.41807995 0.41049011
#  0.40788128 0.42218528 0.08386316 0.12583412 0.12583412 0.12583412
#  0.12587351 0.08386316 0.12583412 0.12583412 0.12583412 0.12587351
#  0.49003964 0.49264209 0.4925802  0.49311484 0.49280427 0.44460767
#  0.44453048 0.44623658 0.44633082 0.44856596 0.41726325 0.41506144
#  0.4090155  0.40429177 0.41038912 0.40974133 0.41807995 0.41049011
#  0.40788128 0.42218528 0.08386316 0.12583412 0.12583412 0.12583412
#  0.12587351 0.08386316 0.12583412 0.12583412 0.12583412 0.12587351
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=0), n_jobs=-1,
#              param_grid={'class_weight': ['balanced', 'balanced_subsampe'],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 10, 15, 20, None],
#                          'min_samples_split': [0.01, 0.1, 0.25, 0.5, 0.75, 1.0],
#                          'n_estimators': [25, 50, 100, 150, 200]},
#              scoring='f1')

# %%
# Getting Best Hyperparameters
print(clf.best_params_, clf.best_score_)
# Out:
# {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 0.01, 'n_estimators': 150} 0.4942473091278655

# %%
# Final Model Test Data
print(clf.score(X_test_numerical, y_test))
# Out:
# 0.4937833037300178

# %% [markdown]
# ### Pre-Processing
#
# #### Listing The Numerical & Categorical Features

# %%
# Numerical Features
numerical_feats = list(df_train.drop(columns='y').select_dtypes(include=np.number).columns)

# Categorical Features
categorical_feats = list(df_train.drop(columns='y').select_dtypes(exclude=np.number).columns)

# %% [markdown]
# #### Placing Pre-Processor

# %%
numeric_preprocessor = StandardScaler()

categorical_preprocessor = OneHotEncoder(handle_unknown="ignore")

# %% [markdown]
# #### Pre-Processor Delegation

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_preprocessor, numerical_feats),
        ("cat", categorical_preprocessor, categorical_feats),
    ])

# %% [markdown]
# #### Setting Pre-Processor Pipeline

# %%
pipe = Pipeline(
    steps=[("preprocessor", preprocessor),
           ("model", RandomForestClassifier(random_state=0))])

# %%
X_train_full = df_train.drop(columns=['y'])
y_train = df_train['y']

X_train_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40689 entries, 17974 to 2732
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        40689 non-null  int64
#  1   job        40689 non-null  object
#  2   marital    40689 non-null  object
#  3   education  40689 non-null  object
#  4   default    40689 non-null  object
#  5   balance    40689 non-null  int64
#  6   housing    40689 non-null  object
#  7   loan       40689 non-null  object
#  8   contact    40689 non-null  object
#  9   day        40689 non-null  int64
#  10  month      40689 non-null  object
#  11  duration   40689 non-null  int64
#  12  campaign   40689 non-null  int64
#  13  pdays      40689 non-null  int64
#  14  previous   40689 non-null  int64
#  15  poutcome   40689 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 5.3+ MB

# %%
X_test_full = df_test.drop(columns=['y'])
y_test = df_test['y']

X_test_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4522 entries, 14001 to 25978
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4522 non-null   int64
#  1   job        4522 non-null   object
#  2   marital    4522 non-null   object
#  3   education  4522 non-null   object
#  4   default    4522 non-null   object
#  5   balance    4522 non-null   int64
#  6   housing    4522 non-null   object
#  7   loan       4522 non-null   object
#  8   contact    4522 non-null   object
#  9   day        4522 non-null   int64
#  10  month      4522 non-null   object
#  11  duration   4522 non-null   int64
#  12  campaign   4522 non-null   int64
#  13  pdays      4522 non-null   int64
#  14  previous   4522 non-null   int64
#  15  poutcome   4522 non-null   object
# dtypes: int64(7), object(9)
# memory usage: 600.6+ KB

# %%
pipe.fit(X_train_full, y_train)

y_pred = pipe.predict(X_test_full)
print(f1_score(y_test, y_pred))
# Out:
# 0.5035971223021583

# %%
hyperparameter_space = { 
"model__n_estimators": [25,50,100,150,200], 
"model__criterion": ["gini", "entropy"], 
"model__class_weight": ["balanced","balanced_subsample"],
"model__min_samples_split": [0.01,0.1,0.25,0.5,0.75,1.0],
}

# %%
# Initiate the Grid Search Class
clf = GridSearchCV(pipe, hyperparameter_space, 
                   scoring = 'f1', cv=5, 
                   n_jobs=-1, refit = True,
                   verbose=2)

# Run the Grid Search CV
clf.fit(X_train_full, y_train)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.01, model__n_estimators=50; total time=   0.8s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.01, model__n_estimators=200; total time=   3.1s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.25, model__n_estimators=25; total time=   0.2s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.25, model__n_estimators=50; total time=   0.3s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.25, model__n_estimators=100; total time=   0.7s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.25, model__n_estimators=200; total time=   1.3s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.75, model__n_estimators=50; total time=   0.1s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.75, model__n_estimators=100; total time=   0.2s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.75, model__n_estimators=200; total time=   0.3s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=1.0, model__n_estimators=150; total time=   0.3s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0.01, model__n_estimators=50; total time=   0.9s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0.01, model__n_estimators=200; total time=   3.1s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0.25, model__n_estimators=25; total time=   0.2s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0.25, model__n_estimators=25; total time=   0.2s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0.25, model__n_estimators=50; total time=   0.4s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0.25, model__n_estimators=150; total time=   1.0s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0.5, model__n_estimators=50; total time=   0.2s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0.5, model__n_estimators=100; total time=   0.5s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0.5, model__n_estimators=200; total time=   0.8s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=1.0, model__n_estimators=25; total time=   0.1s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=1.0, model__n_estimators=50; total time=   0.1s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=1.0, model__n_estimators=200; total time=   0.4s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.01, model__n_estimators=100; total time=   1.8s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.1, model__n_estimators=25; total time=   0.3s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.1, model__n_estimators=50; total time=   0.6s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.1, model__n_estimators=50; total time=   0.6s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.1, model__n_estimators=150; total time=   1.9s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.25, model__n_estimators=100; total time=   0.9s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.25, model__n_estimators=200; total time=   1.8s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.75, model__n_estimators=25; total time=   0.2s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.75, model__n_estimators=25; total time=   0.1s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.75, model__n_estimators=50; total time=   0.3s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.75, model__n_estimators=150; total time=   0.7s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=1.0, model__n_estimators=50; total time=   0.2s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=1.0, model__n_estimators=150; total time=   0.7s
# /opt/anaconda3/envs/HPTP/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.01, model__n_estimators=25; total time=   0.4s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.01, model__n_estimators=150; total time=   2.3s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.1, model__n_estimators=100; total time=   0.9s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.1, model__n_estimators=200; total time=   1.8s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.5, model__n_estimators=25; total time=   0.2s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.5, model__n_estimators=100; total time=   0.5s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.5, model__n_estimators=150; total time=   0.6s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.75, model__n_estimators=150; total time=   0.3s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=1.0, model__n_estimators=25; total time=   0.1s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=1.0, model__n_estimators=100; total time=   0.2s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=1.0, model__n_estimators=200; total time=   0.4s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0.01, model__n_estimators=100; total time=   1.6s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0.1, model__n_estimators=25; total time=   0.3s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0

# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.01, model__n_estimators=50; total time=   0.8s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.01, model__n_estimators=200; total time=   3.2s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.25, model__n_estimators=25; total time=   0.2s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.25, model__n_estimators=50; total time=   0.4s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.25, model__n_estimators=100; total time=   0.6s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.25, model__n_estimators=200; total time=   1.2s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.75, model__n_estimators=25; total time=   0.1s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.75, model__n_estimators=25; total time=   0.1s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.75, model__n_estimators=50; total time=   0.1s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=0.75, model__n_estimators=150; total time=   0.3s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=1.0, model__n_estimators=25; total time=   0.1s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=1.0, model__n_estimators=50; total time=   0.1s
# [CV] END model__class_weight=balanced, model__criterion=gini, model__min_samples_split=1.0, model__n_estimators=150; total time=   0.3s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0.01, model__n_estimators=50; total time=   0.8s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0.01, model__n_estimators=200; total time=   3.1s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0.1, model__n_estimators=200; total time=   1.9s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0.5, model__n_estimators=100; total time=   0.4s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0.5, model__n_estimators=150; total time=   0.7s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=0.75, model__n_estimators=150; total time=   0.3s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=1.0, model__n_estimators=25; total time=   0.1s
# [CV] END model__class_weight=balanced, model__criterion=entropy, model__min_samples_split=1.0, model__n_estimators=100; total time=   0.2s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.01, model__n_estimators=25; total time=   0.5s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.01, model__n_estimators=150; total time=   2.7s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.1, model__n_estimators=100; total time=   1.2s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.1, model__n_estimators=150; total time=   1.8s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.25, model__n_estimators=150; total time=   1.4s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.5, model__n_estimators=100; total time=   0.7s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=0.5, model__n_estimators=200; total time=   1.3s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=1.0, model__n_estimators=25; total time=   0.2s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=1.0, model__n_estimators=50; total time=   0.2s
# [CV] END model__class_weight=balanced_subsample, model__criterion=gini, model__min_samples_split=1.0, model__n_estimators=100; total time=   0.5s
# [CV] END model__class_weight=balanced_subsample, model__criterion=entropy, model__min_samples_split=0.01, model__n_estimators=25; total time=   0.5s
# [CV] END model__class_weight=balanced_subsample, model__criterion=entropy, model__min_samples_split=0.01, model__n_estimators=50; total time=   1.1s
# [CV] END model__class_weight=balanced_subsample, model__criterion=entropy, model__min_samples_split=0.01, model__n_estimators=200; total time=   3.9s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['age',
#                                                                           'balance',
#                                                                           'day',
#                                                                           'duration',
#                                                                           'campaign',
#                                                                           'pdays',
#                                                                           'previous']),
#                                                                         ('cat',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          ['job',
#                                                                           'marital',
#                                                                           'education',
#                                                                           'default',
#                                                                           'housing',
#                                                                           'loan',
#                                                                           'contact',
#                                                                           'month',
#                                                                           'poutcome'])])),
#                                        ('model',
#                                         RandomForestClassifier(random_state=0))]),
#              n_jobs=-1,
#              param_grid={'model__class_weight': ['balanced',
#                                                  'balanced_subsample'],
#                          'model__criterion': ['gini', 'entropy'],
#                          'model__min_samples_split': [0.01, 0.1, 0.25, 0.5,
#                                                       0.75, 1.0],
#                          'model__n_estimators': [25, 50, 100, 150, 200]},
#              scoring='f1', verbose=2)

# %%
clf.best_params_,clf.best_score_
# Out:
# ({'model__class_weight': 'balanced_subsample',
#   'model__criterion': 'gini',
#   'model__min_samples_split': 0.01,
#   'model__n_estimators': 100},
#  np.float64(0.54949186142684))

# %%
clf.score(X_test_full,y_test)
# Out:
# 0.5506072874493927

# %% [markdown]
# ## Random Search
